# %% [markdown]
# # Machine Learning experiment

# %% [markdown]
# Цель этого задания - продемонстрировать, что вы можете подготовить набор данных для анализа, провести эксперименты машинного обучения и тщательно изучить результаты.

# %% [markdown]
# Ссылка на набор данных и описание аттрибутов: http://archive.ics.uci.edu/ml/datasets/Drug+consumption+%28quantified%29

# %% [markdown]
# • Прочтите описание задачи и определите свои входные и выходные переменные. Загрузите данные с помощью pandas и разделите датачет на X (входы) и y (выходы).
# • Подготовьте набор данных: закодируйте категориальные переменные (если есть), обработайте отсутствующие переменные (если есть), синтезируйте новые переменные (если у вас есть интуиция, что они могут быть полезны). При необходимости выполните предварительную обработку целевой переменной (например, объедините различные задачи классификации в одну или преобразуйте целевую переменную в двоичную). Для каждого преобразования дайте четкое объяснение вашей мотивации.
# • Выполните исследовательский анализ данных с помощью визуализации в Seaborn или Matplotlib. Попробуйте найти в данных значимые закономерности, которые можно использовать для конкретизации задачи машинного обучения или для помощи в выборе и настройке моделей машинного обучения. Выполните дополнительную предварительную обработку ваших данных, если ваши выводы предполагают это (опять же, все шаги должны быть мотивированы). Если есть несколько вариантов целевых переменных, вы можете выбрать некоторые из них после этого шага с парой предложений, объясняющих ваш выбор.
# • Разработайте надлежащую процедуру перекрестной проверки; выберите подходящую метрику качества. Выберите подходящую модель машинного обучения; Подберите оптимальный набор гиперпараметров. Используйте подготовленную процедуру перекрестной проверки, чтобы оценить качество прогноза.
# • Проанализируйте полученные результаты (интересные выводы, замечания по экспериментам ML, применимость модели) и сделать общий вывод.

# %% [markdown]
# ### Цель исследования
#
# Т.к. цель четко неопределена - будем исследовать вероятность употребления человеком одного из видов наркотиков (я выбрал ЛСД):
#
# - обучим модели предсказывать вероятность употребления человеком ЛСД;
# - проводём кластеризацию на основе которой постараемся выделить группы которые наиболее\наименее склонны к употреблению.

# %% [markdown]
# ## Описание данных
#
# 1. ID - ид записи (не связано с человеком), бесполезно
# 2. Age - возраст: <br/>
#
# <pre>
# <b>Значение</b> | <b>Реальное значение</b> | <b>Количество</b> | <b>Процентное соотношение</b>
# ------------------------------------------------------------------
# -0.95197 | 18-24             | 643        | 34.11%   <br/>
# -0.07854 | 25-34             | 481        | 25.52% <br/>
# 0.49788  | 35-44             | 356        | 18.89% <br/>
# 1.09449  | 45-54             | 294        | 15.60% <br/>
# 1.82213  | 55-64             | 93         | 4.93% <br/>
# 2.59171  | 65+               | 18         | 0.95% <br/>
#
#
#
# 3. Gender - пол:
# <b>Значение</b> | <b>Реальное значение</b> | <b>Количество</b> | <b>Процентное соотношение</b>
# ------------------------------------------------------------------
# 0.48246  | <b>Женщина</b>           | 942        | 49.97%
# -0.48246 | <b>Мужчина</b>           | 943        | 50.03%
#
#
#
# 4. Education - образование:
# <b>Значение</b> | <b>Реальное значение</b>
# ------------------------------------------------------------------
# -2.43591 | Бросил учёбу до 16 лет
# -1.73790 | Бросил учёбу в 16 лет
# -1.43719 | Бросил учёбу в 17 лет
# -1.22751 | Бросил учёбу в 18 лет
# -0.61113 | Бросил колледж или университет
# -0.05921 | Профессиональное образование
# 0.45468  | Окончил университет
# 1.16365  | Степень магистра
# 1.98437  | Докторская
#
#
# 5. Country - страна:
# <b>Значение</b> | <b>Реальное значение</b>
# ------------------------------------------------------------------
# -0.09765 | Австралия
# 0.24923  | Канада
# -0.46841 | Новая Зеландия
# -0.28519 | Другая
# 0.21128  | Ирландия
# 0.96082  | Англия
# -0.57009 | США
#
#
# 6. Ethnicity - этническая принадлежность:
# <b>Значение</b> | <b>Реальное значение</b>
# ------------------------------------------------------------------
# -0.50212 | Asian
# -1.10702 | Black
# 1.90725  | Mixed-Black/Asian
# 0.12600  | Mixed-White/Asian
# -0.22166 | Mixed-White/Black
# 0.11440  | Other
# -0.31685 | White
#
#
# 7. <b>Nscore</b> - результаты теста (типа личности) на невротизм.
# 8. <b>Escore</b> - результаты теста (типа личности) на экставертна.
# 9. <b>Oscore</b> - результаты теста (типа личности) на открытость.
# 10. <b>Ascore</b> - результаты теста (типа личности) на доброжелательность.
# 11. <b>Cscore</b> - результаты теста (типа личности) на добросовестность.
# 12. <b>Impulsive</b> - результаты теста на импульсивность.
# 13. <b>SS</b> - результаты теста на ощущения.
#
#
# Далее идут качественные признаки употребления того или иного (около)наркотического вещества по следующей метрической системе:
#
# Класс | Обозначение
# <b>CL0</b>   | Никогда не употреблял
# <b>CL1</b>   | Употреблял больше 10 лет назад
# <b>CL2</b>   | Употреблял в течении последних 10 лет
# <b>CL3</b>   | Употреблял в прошлом году
# <b>CL4</b>   | Употреблял в прошлом месяце
# <b>CL5</b>   | Употреблял на прошлой неделе
# <b>CL6</b>   | Употреблял вчера
#
# 14. <b>Alcohol</b> - алкоголь.
# 15. <b>Amphet</b> - амфетамин.
# 16. <b>Amyl</b> - амилнитрит.
# 17. <b>Benzos</b> - бензодиазепин.
# 18. <b>Caff</b> - кофеин.
# 19. <b>Cannabis</b> - конопля.
# 20. <b>Choc</b> - шоколад.
# 21. <b>Coke</b> - кокаин:
# 22. <b>Crack</b> - крэк.
# 23. <b>Ecstasy</b> - экстази.
# 24. <b>Heroin</b> - героин.
# 25. <b>Ketamine</b> - кетамин.
# 26. <b>Legalh</b> - высокое потребление легальных веществ.
# 27. <b>LSD</b> - ЛСД (хотя в описании данных написано что это - акоголь).
# 28. <b>Meth</b> - метадон.
# 29. <b>Mushrooms</b> - психотропные грибы.
# 30. <b>Nicotine</b> - никотин (курение).
# 31. <b>Semer</b> - семерон (?).
# 32. <b>VSA</b> - употребление запрещенных веществ.
#
# </pre>

# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans

# %% [markdown]
# ### Подготовка данных

# %%
# Define the data headers
columns = [
    'id',
    'age', 
    'gender', 
    'education', 
    'country',
    'ethnicity', 
    'neuroticism', 
    'extraversion', 
    'openness',
    'agreeableness',
    'conscientiousness',
    'impulsiveness', 
    'sensation',
    'alcohol',
    'amphet', 
    'amyl', 
    'benzos',
    'caffeine', 
    'cannabis',
    'chocolate',
    'cocaine', 
    'crack', 
    'ecstasy', 
    'heroin',
    'ketamine',
    'legalh', 
    'lsd', 
    'meth',
    'mushrooms', 
    'nicotine',
    'semer', 
    'vsa'
]

# читаем данные
link = 'http://archive.ics.uci.edu/ml/machine-learning-databases/00373/drug_consumption.data'
df = pd.read_csv(link, names=columns)
# убераем бесполезный столбец
df.drop('id', axis=1, inplace=True)

# %%
df
# Out:
#           age   gender  education  country  ethnicity  neuroticism  \
# 0     0.49788  0.48246   -0.05921  0.96082    0.12600      0.31287
# 1    -0.07854 -0.48246    1.98437  0.96082   -0.31685     -0.67825
# 2     0.49788 -0.48246   -0.05921  0.96082   -0.31685     -0.46725
# 3    -0.95197  0.48246    1.16365  0.96082   -0.31685     -0.14882
# 4     0.49788  0.48246    1.98437  0.96082   -0.31685      0.73545
# ...       ...      ...        ...      ...        ...          ...
# 1880 -0.95197  0.48246   -0.61113 -0.57009   -0.31685     -1.19430
# 1881 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685     -0.24649
# 1882 -0.07854  0.48246    0.45468 -0.57009   -0.31685      1.13281
# 1883 -0.95197  0.48246   -0.61113 -0.57009   -0.31685      0.91093
# 1884 -0.95197 -0.48246   -0.61113  0.21128   -0.31685     -0.46725
#
#       extraversion  openness  agreeableness  conscientiousness  ...  ecstasy  \
# 0         -0.57545  -0.58331       -0.91699           -0.00665  ...      CL0
# ...

# %%
display(df.info())
print('-------------------')
display(df.isna().sum())
print('-------------------')
display(df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1885 entries, 0 to 1884
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                1885 non-null   float64
#  1   gender             1885 non-null   float64
#  2   education          1885 non-null   float64
#  3   country            1885 non-null   float64
#  4   ethnicity          1885 non-null   float64
#  5   neuroticism        1885 non-null   float64
#  6   extraversion       1885 non-null   float64
#  7   openness           1885 non-null   float64
#  8   agreeableness      1885 non-null   float64
#  9   conscientiousness  1885 non-null   float64
#  10  impulsiveness      1885 non-null   float64
#  11  sensation          1885 non-null   float64
#  12  alcohol            1885 non-null   object
#  13  amphet             1885 non-null   object
#  14  amyl               1885 non-null   object
# ...

# %%
# данные без пропусков \ дублей

# %%
# переводим категориальные переменные в количественные
addictions = list(df.columns)[12:]

for addict in addictions:
    df[addict] = df[addict].apply(lambda x: 0 if x == 'CL0' else 1)

# %%
# выбираем целевую переменную

#target = 'alcohol'
#target = 'cocaine'
#target = 'cannabis'
target = 'lsd'

# %%
# оставляем только необходимые данные
weights = [
    'age', 
    'gender', 
    'education', 
    'country', 
    'ethnicity', 
    'neuroticism',
    'extraversion',
    'openness',
    'agreeableness',
    'impulsiveness',
    'sensation'
]

df_clean = df[
    weights + [
        target
    ]
]

#for addict in addictions:
#    display(df.groupby(addict).agg('mean').T.style.highlight_max(axis=1))

# %%
df_clean
# Out:
#           age   gender  education  country  ethnicity  neuroticism  \
# 0     0.49788  0.48246   -0.05921  0.96082    0.12600      0.31287
# 1    -0.07854 -0.48246    1.98437  0.96082   -0.31685     -0.67825
# 2     0.49788 -0.48246   -0.05921  0.96082   -0.31685     -0.46725
# 3    -0.95197  0.48246    1.16365  0.96082   -0.31685     -0.14882
# 4     0.49788  0.48246    1.98437  0.96082   -0.31685      0.73545
# ...       ...      ...        ...      ...        ...          ...
# 1880 -0.95197  0.48246   -0.61113 -0.57009   -0.31685     -1.19430
# 1881 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685     -0.24649
# 1882 -0.07854  0.48246    0.45468 -0.57009   -0.31685      1.13281
# 1883 -0.95197  0.48246   -0.61113 -0.57009   -0.31685      0.91093
# 1884 -0.95197 -0.48246   -0.61113  0.21128   -0.31685     -0.46725
#
#       extraversion  openness  agreeableness  impulsiveness  sensation  lsd
# 0         -0.57545  -0.58331       -0.91699       -0.21712   -1.18084    0
# ...

# %%
# в этой визуализации нет смысла - все признаки у нас нормализованные
display(df_clean.groupby(target).agg('mean').T.style.highlight_max(axis=1))
# Out:
# <style  type="text/css" >
# #T_908446f2_2cfb_11ec_887d_718ca5432c85row0_col0,#T_908446f2_2cfb_11ec_887d_718ca5432c85row1_col0,#T_908446f2_2cfb_11ec_887d_718ca5432c85row2_col0,#T_908446f2_2cfb_11ec_887d_718ca5432c85row3_col0,#T_908446f2_2cfb_11ec_887d_718ca5432c85row4_col1,#T_908446f2_2cfb_11ec_887d_718ca5432c85row5_col1,#T_908446f2_2cfb_11ec_887d_718ca5432c85row6_col0,#T_908446f2_2cfb_11ec_887d_718ca5432c85row7_col1,#T_908446f2_2cfb_11ec_887d_718ca5432c85row8_col0,#T_908446f2_2cfb_11ec_887d_718ca5432c85row9_col1,#T_908446f2_2cfb_11ec_887d_718ca5432c85row10_col1{
#             background-color:  yellow;
#         }</style><table id="T_908446f2_2cfb_11ec_887d_718ca5432c85" ><thead>    <tr>        <th class="index_name level0" >lsd</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
# построение гистограмм распределения признаков
users = df_clean[df_clean[target] == 1]
never_used = df_clean[df_clean[target] == 0]

for weight in weights:
    plt.figure(figsize=(16, 8))
    
    try:
        sns.distplot(users[weight])
        sns.distplot(never_used[weight])
    except RuntimeError as re:
        if str(re).startswith("Selected KDE"):
            sns.distplot(users[weight], kde_kws={'bw': 0.1})
            sns.distplot(never_used[weight], kde_kws={'bw': 0.1})
        else:
            raise re
        
    plt.legend(['Употребление', 'Никогда не пробовали'])
    plt.title('Признак - ' + weight)
    plt.xlabel('')
    plt.show()

# %%
for weight in weights:
    plt.figure(figsize=(12, 6))
    sns.boxplot(
        x=target, 
        y=df_clean[weight], 
        data=df_clean
    )
    plt.xticks((0, 1), ('Никогда не пробовали', 'Употребление'))
    plt.xlabel('')
    plt.ylabel('')
    plt.title('Признак - ' + weight)
    plt.show()

# %%
cm = df_clean.corr()
plt.figure(figsize=(14, 10))
sns.heatmap(cm, annot=True, fmt='0.2f', linewidths=.5)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2> Промежуточный итог:</h2>
# <br/>
#
# - возраст не влияет на употребление \ неупотребление (оно +- одинаковое во всех возрастных категориях);
# - мужчины употребляли ЛСД чаще женщин (видно на гистограмме распределения признаков);
# - больше всего склонность к употреблению среди тех, кто бросил колледж или университет, те, кто окончили унверситет - будут употреблять наименее вероятно;
# - в Новой Зеландии (или "другой" стране) наибольшая доля "употребителей", в то время как в Англии почти никто не употреблял ЛСД;
# - наибольшая склонность к употреблению - у "Mixed-Black/Asian"
#
# Далее идут связи употребления с результатами тестов, их пропускам.
#
# - у нас нет сильной корреляции между несколькими переменными (светлых квадратов на графике) и это говорит об отсутствии мультиколлениарности (лучше всего избавляться от одной из таких переменных, чтобы обученная модель работала объективно);
# - наибольшая связь употребления лсд - с openness, impulsiveness, sensation.
# </div>

# %% [markdown]
# ## Model

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2> Построим модель бинарной классификации пользователей, где целевой признак - факт употребления ЛСД.</h2>
# <br/>
#
# 1) Разобъем данные на обучающую и валидационную выборки функцией train_test_split(); <br/>
# 2) Обучим модель на train-выборке логистической регрессией и случайным лесом; <br/>
# 2) Оценим метрики accuracy, precision и recall для обеих моделей на валидационной выборке. Сравним по ним модели.
# </div>

# %%
X = df_clean.drop(target, axis=1)
y = df[target]

# %%
# random_state=0 позволяет нам каждый раз получать одни и те же значения при разделении выборки
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ### Логистическая регрессия

# %%
model = LogisticRegression()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
probabilities =  model.predict_proba(X_test)[:,1]

print('Accuracy | Нет баланса классов: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, predictions)))
print('F1: {:.2f}'.format(f1_score(y_test, predictions)))
# Out:
# Accuracy | Нет баланса классов: 0.79
# Precision: 0.74
# Recall: 0.74
# F1: 0.74

# %% [markdown]
# ### Случайный лес

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train_st = scaler.transform(X_train)
X_test_st = scaler.transform(X_test)

rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0) 
rf_model.fit(X_train_st, y_train)
rf_predictions = rf_model.predict(X_test_st) 
rf_probabilities = rf_model.predict_proba(X_test_st)[:,1]

print('Accuracy | Нет баланса классов: {:.2f}'.format(accuracy_score(y_test, rf_predictions)))
print('Precision: {:.2f}'.format(precision_score(y_test, rf_predictions)))
print('Recall: {:.2f}'.format(recall_score(y_test, rf_predictions)))
print('F1: {:.2f}'.format(f1_score(y_test, rf_predictions)))
# Out:
# Accuracy | Нет баланса классов: 0.77
# Precision: 0.71
# Recall: 0.71
# F1: 0.71

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2> Вывод:</h2>
# <br/>
#
# Доля правильных прогнозов и полнота чуть выше в модели логистической регрессии; <br/>
# Таким образом, модель логистической регрессии показала себя лучше. <br/>
#
# </div>

# %% [markdown]
# ## Clusterization

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2> Проведем кластеризацию пользователей без столбца целевого значения:</h2>
# <br/>
#
# - Стандартизируем данные;
# - Построим матрицу расстояний функцией linkage() на стандартизированной матрице признаков и нарисуем дендограмму;
# - Обучим модель кластеризации на основе алгоритма K-Means и спрогнозируем кластеры клиентов (возьмём n=5 кластеров).
#
# </div>

# %%
df_sс = df.drop([target], axis=1)
df_columns_list = df_sс.columns
df_sс = StandardScaler().fit_transform(df_sс)
df_sс = pd.DataFrame(df_sс, columns=df_columns_list).astype('float64')

# %%
linked = linkage(df_sс, method = 'ward')

# %%
plt.figure(figsize=(16, 8))  
dendrogram(linked, orientation = 'top')
plt.title('Иерархическая кластеризация', fontsize=15)
plt.show()

# %%
# видим 4 явно выраженных кластера

# %%
km = KMeans(n_clusters=4)
labels = km.fit_predict(df_sс)
df_clean['cluster'] = labels
# Out:
# /home/sergey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_clean.cluster.value_counts()
# Out:
# 1    714
# 2    449
# 0    419
# 3    303
# Name: cluster, dtype: int64

# %%
df_clean.groupby('cluster').mean().T
# Out:
# cluster               0         1         2         3
# age            0.197435  0.441015 -0.652152 -0.130541
# gender        -0.044907  0.204066 -0.168700 -0.170374
# education      0.184998  0.274577 -0.396035 -0.339659
# country        0.654299  0.813908 -0.275730 -0.202250
# ethnicity     -0.303108 -0.335482 -0.289061 -0.287883
# neuroticism   -0.108212 -0.181499  0.092745  0.440187
# extraversion   0.137518  0.039469 -0.042718 -0.220884
# openness       0.012065 -0.522489  0.569048  0.367961
# agreeableness -0.032656  0.259082 -0.137713 -0.362807
# impulsiveness  0.064444 -0.475160  0.371271  0.525294
# sensation      0.092121 -0.638604  0.547014  0.546373
# lsd            0.610979  0.042017  0.583519  0.884488

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2> Вывод по кластеризации:</h2>
# <br/>
#
# <b>Кластер 0</b>:
#
# - В кластере 419 наблюдений;
# - Склонность к употреблению выше средней- 61%;
# - Возрастная каитегория - ближе к 35-44, чем к 25-34;
# - Мужчин и женщин примерно одинакого (незначительно больше мужчин);
# - Образование - или окончил проф. училище или университет;
# - Этническая принадлежность - скорее "Mixed-White/Asian".
#
# <b>Кластер 1</b>:
#
# - Самый многочисленный кластер - 714 наблюдений;
# - Самая низкая склонность к употреблению - 4%;
# - Возраст - 35-44;
# - Наиболее вероятно - это женщина;
# - Окончила университет (высшее образование);
# - Живёт в Англии.
#
# <b>Кластер 2</b>:
#
# - В кластере 449 наблюдений;
# - Склонность к употреблению выше средней- 58%;
# - Возраст - 18-24;
# - Наиболее вероятно это мужчина;
# - Бросил колледж или университет;
# - Нет информации по стране ("другая");
# - Этническая принадлежность - "White".
#
# <b>Кластер 3</b>:
#
# - В кластере 303 наблюдения;
# - Самые склонные к употреблению (почти 90%);
# - Возраст - 25-34;
# - Наиболее вероятно это мужчина;
# - В равной степени Бросил колледж/университет или получил высшее образование;
# - Нет информации по стране ("другая");
# - Этническая принадлежность - "White".
#
#
# Кластеры могут показаться похожими (например 2 и 3 по описанным метрикам практически идентичны за исключением % употребления), но это из-за того, что я не описывал метрики психологических тестов (для их интерпретации нужно больше времени, чем у меня имеется; например явно видно что 2 кластер сильно отличается от 3 по невротицизму и экстраверсии).
#
# </div>

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x=df_clean['gender'], hue='cluster', data=df_clean)
plt.title('Признак - ' + 'gender')
plt.xticks((0, 1), ('Мужчина', 'Женщина'))
plt.xlabel('')
plt.ylabel('Количество наблюдений')
# Out:
# Text(0, 0.5, 'Количество наблюдений')

# %%
for weight in weights:
    
    plt.figure(figsize=(5, 5))
    sns.boxplot(x='cluster', y=df_clean[weight], data=df_clean)
    plt.title('Признак - ' + weight)
    plt.xlabel('№ Кластера')
    plt.ylabel('')
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2> Вывод:</h2>
# <br/>
#
# В целом графики подтверждают ранее сделанные выводы.
#
# </div>
